# %% [markdown]
# # a. Importieren der Daten in ein Pandas Dataframe

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel("data.xlsx")

columns = {"X1 transaction date": "transaction date",
           "X2 house age": "house age",
           "X3 distance to the nearest MRT station": "distance to the nearest MRT station",
           "X4 number of convenience stores": "number of convenience stores",
           "X5 latitude": "latitude",
           "X6 longitude": "longitude",
           "Y house price of unit area": "house price of unit area"}

df.rename(columns=columns, inplace=True)
df
# Out:
#       No  transaction date  house age  distance to the nearest MRT station
# 0      1       2012.916667       32.0                             84.87882  \
# 1      2       2012.916667       19.5                            306.59470
# 2      3       2013.583333       13.3                            561.98450
# 3      4       2013.500000       13.3                            561.98450
# 4      5       2012.833333        5.0                            390.56840
# ..   ...               ...        ...                                  ...
# 409  410       2013.000000       13.7                           4082.01500
# 410  411       2012.666667        5.6                             90.45606
# 411  412       2013.250000       18.8                            390.96960
# 412  413       2013.000000        8.1                            104.81010
# 413  414       2013.500000        6.5                             90.45606
#
#      number of convenience stores  latitude  longitude
# ...

# %% [markdown]
# # b. Visualisierung der Verteilung der Merkmale nach Z-Standardisierung in Boxplots

# %%
plt.figure(figsize=(25, 8), dpi=150)
df_z_transformed = (df - df.mean()) / df.std()  # Dataframe mittels Z-Transformation skalieren
sns.boxplot(data=df_z_transformed)
# Out:
# <Axes: >

# %% [markdown]
# # c. Visualisierung des linearen Zusammenhangs zwischen y: 'house price of unit area' und
# # jedem einzelnen Merkmal xi in Streuungsdiagrammen

# %%
plt.figure(figsize=(15, 8), dpi=100)
plt.title(label="Linearer Zusammenhang zwischen Merkmal x: 'transaction date' und Zielmerkmal y", fontsize=20,
          fontweight="bold")

#sns.scatterplot(x="transaction date", y="house price of unit area", data=df, color='blue')
sns.regplot(x=df['transaction date'], y=df['house price of unit area'], color='green')
# Out:
# <Axes: title={'center': "Linearer Zusammenhang zwischen Merkmal x: 'transaction date' und Zielmerkmal y"}, xlabel='transaction date', ylabel='house price of unit area'>

# %%
plt.figure(figsize=(15, 8), dpi=100)
plt.title(label="Linearer Zusammenhang zwischen Merkmal x2: 'house age' und Zielmerkmal y", fontsize=20,
          fontweight="bold")  #Überschrift hinzugefügt

#sns.scatterplot(x="house age", y="house price of unit area", data=df, color='blue')
sns.regplot(x=df['house age'], y=df['house price of unit area'], color='green')
# Out:
# <Axes: title={'center': "Linearer Zusammenhang zwischen Merkmal x2: 'house age' und Zielmerkmal y"}, xlabel='house age', ylabel='house price of unit area'>

# %%
plt.figure(figsize=(15, 8), dpi=100)
plt.title(label="Linearer Zusammenhang zwischen Merkmal x3: 'distance to the nearest MRT station' und Zielmerkmal y", fontsize=20,
          fontweight="bold")  #Überschrift hinzugefügt

#sns.scatterplot(x="distance to the nearest MRT station", y="house price of unit area", data=df, color='blue')
sns.regplot(x=df['distance to the nearest MRT station'], y=df['house price of unit area'], color='green')
# Out:
# <AxesSubplot: title={'center': "Linearer Zusammenhang zwischen Merkmal x3: 'distance to the nearest MRT station'\nund Zielmerkmal y als Streuungsdiagramm"}, xlabel='distance to the nearest MRT station', ylabel='house price of unit area'>

# %%
plt.figure(figsize=(15, 8), dpi=100)
plt.title(label="Linearer Zusammenhang zwischen Merkmal x4: 'number of convenience stores'\nund Zielmerkmal y", fontsize=20,
          fontweight="bold")

#sns.scatterplot(x="number of convenience stores", y="house price of unit area", data=df, color='green')
sns.regplot(x=df['number of convenience stores'], y=df['house price of unit area'], color='green')
# Out:
# <AxesSubplot: title={'center': "Linearer Zusammenhang zwischen Merkmal x4: 'number of convenience stores'\nund Zielmerkmal y als Streuungsdiagramm"}, xlabel='number of convenience stores', ylabel='house price of unit area'>

# %%
plt.figure(figsize=(15, 8), dpi=100)
plt.title(label="Linearer Zusammenhang zwischen Merkmal x5: 'latitude'\nund Zielmerkmal y", fontsize=20,
          fontweight="bold")

#sns.scatterplot(x="latitude", y="house price of unit area", data=df, color='blue')
sns.regplot(x=df['latitude'], y=df['house price of unit area'], color='green')
# Out:
# <AxesSubplot: title={'center': "Linearer Zusammenhang zwischen Merkmal x5: 'latitude'\nund Zielmerkmal y als Streuungsdiagramm"}, xlabel='latitude', ylabel='house price of unit area'>

# %%
plt.figure(figsize=(15, 8), dpi=100)
plt.title(label="Linearer Zusammenhang zwischen Merkmal x6: 'longitude' und Zielmerkmal y", fontsize=20,
          fontweight="bold")

#sns.scatterplot(x="longitude", y="house price of unit area", data=df, color='green')
sns.regplot(x=df['longitude'], y=df['house price of unit area'], color='green')
# Out:
# <AxesSubplot: title={'center': "Linearer Zusammenhang zwischen Merkmal x6: 'longitude und Zielmerkmal y als Streuungsdiagramm"}, xlabel='longitude', ylabel='house price of unit area'>

# %% [markdown]
# # d. Bestimmen Sie die Korrelationskoeffizienten zwischen y und jedem Merkmal x i und
# # interpretieren Sie die Zusammenhänge

# %%
df['house price of unit area'].corr(df['transaction date'])
# Out:
# 0.08752927169725987

# %%
plt.title(label="Korrelationskoeffizent zwischen Merkmal transaction date und Zielmerkmal house price of unit area", fontsize=20, fontweight="bold")
sns.regplot(x=df['transaction date'], y=df['house price of unit area'], color='blue')
# Out:
# <Axes: title={'center': 'Korrelationskoeffizent zwischen Merkmal transaction date und Zielmerkmal house price of unit area'}, xlabel='transaction date', ylabel='house price of unit area'>

# %%
df['house price of unit area'].corr(df['house age'])
# Out:
# -0.21056704627721676

# %%
plt.title(label="Korrelationskoeffizent zwischen Merkmal house age und Zielmerkmal house price of unit area", fontsize=20, fontweight="bold")

sns.regplot(x=df['house age'], y=df['house price of unit area'], color='blue')
# Out:
# <Axes: title={'center': 'Korrelationskoeffizent zwischen Merkmal house age und Zielmerkmal house price of unit area'}, xlabel='house age', ylabel='house price of unit area'>

# %%
df['house price of unit area'].corr(df['distance to the nearest MRT station'])
# Out:
# -0.6736128553689182

# %%
plt.title(label="Korrelationskoeffizent zwischen Merkmal distance of the nearest MRT station und Zielmerkmal house price of unit area", fontsize=20, fontweight="bold")

sns.regplot(x=df['distance to the nearest MRT station'], y=df['house price of unit area'], color='blue')
# Out:
# <Axes: title={'center': 'Korrelationskoeffizent zwischen Merkmal distance of the nearest MRT station und Zielmerkmal house price of unit area'}, xlabel='distance to the nearest MRT station', ylabel='house price of unit area'>

# %%
df['house price of unit area'].corr(df['number of convenience stores'])
# Out:
# 0.5710049111111483

# %%
plt.title(label="Korrelationskoeffizent zwischen Merkmal number of convenience stores und Zielmerkmal house price of unit area", fontsize=20, fontweight="bold")

sns.regplot(x=df['number of convenience stores'], y=df['house price of unit area'], color='blue')
# Out:
# <Axes: title={'center': 'Korrelationskoeffizent zwischen Merkmal number of convenience stores und Zielmerkmal house price of unit area'}, xlabel='number of convenience stores', ylabel='house price of unit area'>

# %%
df['house price of unit area'].corr(df['latitude'])
# Out:
# 0.5463066525036047

# %%
plt.title(label="Korrelationskoeffizent zwischen Merkmal latitude und Zielmerkmal house price of unit area", fontsize=20, fontweight="bold")

sns.regplot(x=df['latitude'], y=df['house price of unit area'], color='blue')
# Out:
# <Axes: title={'center': 'Korrelationskoeffizent zwischen Merkmal latitude und Zielmerkmal house price of unit area'}, xlabel='latitude', ylabel='house price of unit area'>

# %%
df['house price of unit area'].corr(df['longitude'])
# Out:
# 0.5232865070287562

# %%
plt.title(label="Korrelationskoeffizent zwischen Merkmal latitude und Zielmerkmal house price of unit area", fontsize=20, fontweight="bold")

sns.regplot(x=df['longitude'], y=df['house price of unit area'], color='blue')
# Out:
# <Axes: title={'center': 'Korrelationskoeffizent zwischen Merkmal latitude und Zielmerkmal house price of unit area'}, xlabel='longitude', ylabel='house price of unit area'>
